# %%
silver_table = "michelin_jayna_2395498957451879.quickstart_schema.users_silver"
gold_table = "michelin_jayna_2395498957451879.quickstart_schema.users_gold"

# %%
spark.read.table(silver_table).groupBy("country").count().write.mode("overwrite").saveAsTable(gold_table)

# %%
spark.read.table(gold_table).display()
