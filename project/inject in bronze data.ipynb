# %%
# %sql
Create Schema michelin_jayna_2395498957451879.project_schema

# %%
from pyspark.sql.functions import *

spark.read.csv(
    path="dbfs:/FileStore/michelin/ecommerce/orders_001.csv", header=True, inferSchema=True
).write.mode("overwrite").saveAsTable("michelin_jayna_2395498957451879.project_schema.orders_bronze").withColumn(
    "timestamp", current_timestamp()
)

# %%
spark.read.csv(
    path="dbfs:/FileStore/michelin/ecommerce/products.csv", header=True, inferSchema=True
).write.mode("overwrite").saveAsTable("michelin_jayna_2395498957451879.project_schema.products_bronze")

# %%
spark.read.csv(
    path="dbfs:/FileStore/michelin/ecommerce/customers.csv", header=True, inferSchema=True
).write.mode("overwrite").saveAsTable("michelin_jayna_2395498957451879.project_schema.customers_bronze")
